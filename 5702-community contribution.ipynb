# %% [markdown]
# ## Introduction to pyecharts
# Pyecharts is a powerful data visualization tool which combines 'python' and 'echarts'. In this article, we will explain detailed usage rules for pyecharts.

# %% [markdown]
# ### preface
# We all know Matplotlib, a visualization tool on python. A few days ago, when we did a spark project, we used ecarts, a visualization JS tool open source by Baidu. There are many types of visualization, but we have to import JS library to run on Java Web project. We tend to use Python more, so we wonder if there is a combination of Python and ecarts.

# %% [markdown]
# ### Installation
# Firstly open the terminal and input:

# %%
pip install pyecharts
# Out:
# Collecting pyecharts
#   Downloading pyecharts-1.9.0-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 332 kB/s eta 0:00:01
# Requirement already satisfied: simplejson in /Users/michelle/opt/anaconda3/lib/python3.7/site-packages (from pyecharts) (3.17.0)
# Requirement already satisfied: prettytable in /Users/michelle/opt/anaconda3/lib/python3.7/site-packages (from pyecharts) (0.7.2)
# Requirement already satisfied: jinja2 in /Users/michelle/opt/anaconda3/lib/python3.7/site-packages (from pyecharts) (2.10.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/michelle/opt/anaconda3/lib/python3.7/site-packages (from jinja2->pyecharts) (1.1.1)
# Installing collected packages: pyecharts
# Successfully installed pyecharts-1.9.0
# WARNING: You are using pip version 21.0; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/michelle/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# However, we found that due to the firewall, the download will be broken and slow, leading to download failure. So it is recommended to download through Tsinghua mirror. After we download successfully, we can go to next step.

# %% [raw]
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pyecharts

# %% [markdown]
# ### Usage Examples

# %% [markdown]
# Before using, we want to emphasize one point: the encoding problem of python2.X and python3.X. You can regard it as the default Unicode encoding in python 3.X, but it is not the default in python2.X. The reason is that its bytes object definition is confusing, and pycharts uses unicode encoding to handle strings and files. So when you use python2.X, be sure to insert this code:

# %%
from __future__ import unicode_literals
import os
import pyecharts
pyecharts.__version__
# Out:
# '0.5.11'

# %% [markdown]
# Now let's officially use pycharts. Here we directly use the official data:
# ### Bar chart

# %%
from pyecharts import Bar
## column
columns = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
## data
data1 = [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]
data2 = [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]
## title
bar = Bar("Bar chart", "Annual precipitation and evaporation")
## Add data and configuration items of histogram
bar.add("precipitation", columns, data1, mark_line=["average"], mark_point=["max", "min"])
bar.add("evaporation", columns, data2, mark_line=["average"], mark_point=["max", "min"])
#Render will generate a local HTML file, which is generated in the current directory by default render.html
# bar.render()
#You can pass in path parameters such as bar.render (" mycharts.html ")
#You can output graphics in jupyter, such as bar.render_ notebook()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a1a3f5482a0043ed84008da7ea990d59" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a1a3f5482a0043ed84008da7ea990d59 = echarts.init(document.getElementById('a1a3f5482a0043ed84008da7ea990d59'), 'light', {renderer: 'canvas'});
#
# var option_a1a3f5482a0043ed84008da7ea990d59 = {
#     "title": [
#         {
#             "text": "Bar chart",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 214954,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "precipitation",
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 214954
#         },
#         {
#             "type": "bar",
#             "name": "evaporation",
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 214954
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "precipitation",
#                 "evaporation"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lin

# %% [markdown]
# A few simple lines of code can visualize the data very well, and it's still dynamic. Here we recommend jupyter. Pyecharts starts with version v0.1.9.2. You can directly represent the chart by calling the instance on jupyter (for example, calling bar directly above), which is very convenient.
#
# There are more than 20 kinds of charts supported by pyecharts. Next, we use the data above to generate several common charts for data mining.

# %% [markdown]
# ### Pie chart

# %%
from pyecharts import Pie
## Set the main title and subtitle;set the center of the title and set the width to 900
pie = Pie("pie chart", "Annual precipitation and evaporation",title_pos='center',width=900)
## Add the data, set the coordinate position to [25, 50] and the colors option above will not be displayed.
pie.add("precipitation", columns, data1 ,center=[25,50],is_legend_show=False)
## Add the data, set the coordinate position to [75, 50] and the colors option above will not be displayed.
pie.add("evaporation", columns, data2 ,center=[75,50],is_legend_show=False,is_label_show=True)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="46625480dca743fbb76d241bf0e0a3cd" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_46625480dca743fbb76d241bf0e0a3cd = echarts.init(document.getElementById('46625480dca743fbb76d241bf0e0a3cd'), 'light', {renderer: 'canvas'});
#
# var option_46625480dca743fbb76d241bf0e0a3cd = {
#     "title": [
#         {
#             "text": "pie chart",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2408188,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "precipitation",
#             "data": [
#                 {
#                     "name": "Jan",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "Feb",
#                     "value": 4.9
#                 },
#                 {
#                     "name": "Mar",
#                     "value": 7.0
#                 },
#                 {
#                     "name": "Apr",
#                     "value": 23.2
#                 },
#                 {
#                     "name": "May",
#                     "value": 25.6
#                 },
#                 {
#                     "name": "Jun",
#                     "value": 76.7
#                 },
#                 {
#                     "name": "Jul",
#                     "value": 135.6
#                 },
#                 {
#                     "name": "Aug",
#                     "value": 162.2
#                 },
#                 {
#                     "name": "Sep",
#                     "value": 32.6
#                 },
#                 {
#                     "name": "Oct",
#                     "value": 20.0
#                 },
#                 {
#                     "name": "Nov",
#                     "value": 6.4
#                 },
#                 {
#                     "name": "Dec",
#                     "value": 3.3
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2408188
#         },
#         {
#             "type": "pie",
#             "name": "evaporation",
#             "data": [
#                 {
#                     "name": "Jan",
#                     "value": 2.6
#                 },
#                 {
#                     "name": "Feb",
#                     "value": 5.9
#                 },
#                 {
#                     "name": "Mar",
#                     "value": 9.0
#                 },
#                 {
#                     "name": "Apr",
#                     "value": 26.4
#                 },
#                 {
#                     "name": "May",
#                     "value": 28.7
#                 },
#                 {
#                     "name": "Jun",
#                     "value": 70.7
#                 },
#                 {
#                     "name": "Jul",
#                     "value": 175.6
#                 },
#                 {
#                     "name": "Aug",
#                     "value": 182.2
#                 },
#                 {
#                     "name": "Sep",
#                     "value": 48.7
#                 },
#                 {
#                     "name": "Oct",
#                     "value": 18.8
#                 },
#                 {
#                     "name": "Nov",
#                     "value": 6.0
#                 },
#                 {
#                     "name": "Dec",
#                     "value": 2.3
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2408188
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ],
#             "selectedMode": "multiple",
#             "show": false,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_46625480dca743fbb76d241bf0e0a3cd.setOption(option_46625480dca743fbb76d241bf0e0a3cd);
#
#     });
# </script>

# %% [markdown]
# ### Boxplot

# %%
from pyecharts import Boxplot 
boxplot = Boxplot("Boxplot", "Annual precipitation and evaporation")
x_axis = ['precipitation','evaporation']
y_axis = [data1,data2]
## prepare_data method can convert data into nested interval [min, Q1, median (or Q2), Q3, Max].
yaxis = boxplot.prepare_data(y_axis)       
boxplot.add("Weather statistics", x_axis, yaxis)
boxplot
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3aac729a5bbe48b7be3a7c0577410571" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3aac729a5bbe48b7be3a7c0577410571 = echarts.init(document.getElementById('3aac729a5bbe48b7be3a7c0577410571'), 'light', {renderer: 'canvas'});
#
# var option_3aac729a5bbe48b7be3a7c0577410571 = {
#     "title": [
#         {
#             "text": "Boxplot",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 946813,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "Weather statistics",
#             "data": [
#                 [
#                     2.0,
#                     5.275,
#                     21.6,
#                     65.67500000000001,
#                     162.2
#                 ],
#                 [
#                     2.3,
#                     5.925000000000001,
#                     22.6,
#                     65.2,
#                     182.2
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 946813
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Weather statistics"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "precipitation",
#                 "evaporation"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_3aac729a5bbe48b7be3a7c0577410571.setOption(option_3aac729a5bbe48b7be3a7c0577410571);
#
#     });
# </script>

# %% [markdown]
# ## Line chart

# %%
from pyecharts import Line
line = Line("Line chart","Annual precipitation and evaporation")
## is_ label_ Show is to set whether the data above is displayed
line.add("precipitation", columns, data1, is_label_show=True)
line.add("evaporation", columns, data2, is_label_show=True)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="66ced039cf5b498f8c52d7262c4a3f4a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_66ced039cf5b498f8c52d7262c4a3f4a = echarts.init(document.getElementById('66ced039cf5b498f8c52d7262c4a3f4a'), 'light', {renderer: 'canvas'});
#
# var option_66ced039cf5b498f8c52d7262c4a3f4a = {
#     "title": [
#         {
#             "text": "Line chart",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6855707,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "precipitation",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "Jan",
#                     2.0
#                 ],
#                 [
#                     "Feb",
#                     4.9
#                 ],
#                 [
#                     "Mar",
#                     7.0
#                 ],
#                 [
#                     "Apr",
#                     23.2
#                 ],
#                 [
#                     "May",
#                     25.6
#                 ],
#                 [
#                     "Jun",
#                     76.7
#                 ],
#                 [
#                     "Jul",
#                     135.6
#                 ],
#                 [
#                     "Aug",
#                     162.2
#                 ],
#                 [
#                     "Sep",
#                     32.6
#                 ],
#                 [
#                     "Oct",
#                     20.0
#                 ],
#                 [
#                     "Nov",
#                     6.4
#                 ],
#                 [
#                     "Dec",
#                     3.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6855707
#         },
#         {
#             "type": "line",
#             "name": "evaporation",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "Jan",
#                     2.6
#                 ],
#                 [
#                     "Feb",
#                     5.9
#                 ],
#                 [
#                     "Mar",
#                     9.0
#                 ],
#                 [
#                     "Apr",
#                     26.4
#                 ],
#                 [
#                     "May",
#                     28.7
#                 ],
#                 [
#                     "Jun",
#                     70.7
#                 ],
#                 [
#                     "Jul",
#                     175.6
#                 ],
#                 [
#                     "Aug",
#                     182.2
#                 ],
#                 [
#                     "Sep",
#                     48.7
#                 ],
#                 [
#                     "Oct",
#                     18.8
#                 ],
#                 [
#                     "Nov",
#                     6.0
#                 ],
#                 [
#                     "Dec",
#                     2.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6855707
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "precipitation",
#                 "evaporation"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,

# %% [markdown]
# ### Radar chart

# %%
from pyecharts import Radar
radar = Radar("Radar chart", "Annual precipitation and evaporation")
## Since the data of radar chart must be multidimensional data, we need to do some pre-processing here
radar_data1 = [[2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]]
radar_data2 = [[2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]]
## Set the maximum value of column. In order to make the radar chart more intuitive, the maximum value of month here is set differently.
schema = [ 
    ("Jan", 5), ("Feb",10), ("Mar", 10),
    ("Apr", 50), ("May", 50), ("Jun", 200),
    ("Jul", 200), ("Aug", 200), ("Sep", 50),
    ("Oct", 50), ("Nov", 10), ("Dec", 5)
]
radar.config(schema)
radar.add("precipitation",radar_data1)
## Generally, it is the same color by default. Here, in order to distinguish easily, we need to set the color of different item
radar.add("evaporation",radar_data2,item_color="#1C86EE")
radar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="56bab656a9624f1ea32fd47dc40b7276" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_56bab656a9624f1ea32fd47dc40b7276 = echarts.init(document.getElementById('56bab656a9624f1ea32fd47dc40b7276'), 'light', {renderer: 'canvas'});
#
# var option_56bab656a9624f1ea32fd47dc40b7276 = {
#     "title": [
#         {
#             "text": "Radar chart",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2894887,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "radar",
#             "name": "precipitation",
#             "data": [
#                 [
#                     2.0,
#                     4.9,
#                     7.0,
#                     23.2,
#                     25.6,
#                     76.7,
#                     135.6,
#                     162.2,
#                     32.6,
#                     20.0,
#                     6.4,
#                     3.3
#                 ]
#             ],
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "evaporation",
#             "data": [
#                 [
#                     2.6,
#                     5.9,
#                     9.0,
#                     26.4,
#                     28.7,
#                     70.7,
#                     175.6,
#                     182.2,
#                     48.7,
#                     18.8,
#                     6.0,
#                     2.3
#                 ]
#             ],
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#1C86EE"
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "precipitation",
#                 "evaporation"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "radar": {
#         "indicator": [
#             {
#                 "name": "Jan",
#                 "max": 5
#             },
#             {
#                 "name": "Feb",
#                 "max": 10
#             },
#             {
#                 "name": "Mar",
#                 "max": 10
#             },
#             {
#                 "name": "Apr",
#                 "max": 50
#             },
#             {
#                 "name": "May",
#                 "max": 50
#             },
#             {
#                 "name": "Jun",
#                 "max": 200
#             },
#             {
#                 "name": "Jul",
#                 "max": 200
#             },
#             {
#                 "name": "Aug",
#                 "max": 200
#             },
#             {
#                 "name": "Sep",
#                 "max": 50
#             },
#             {
#                 "name": "Oct",
#                 "max": 50
#             },
#             {
#                 "name": "Nov",
#                 "max": 10
#             },
#             {
#                 "name": "Dec",
#                 "max": 5
#             }
#         ],
#         "name": {
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             }
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 1
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_56bab656a9624f1ea32fd47dc40b7276.setOption(option_56bab656a9624f1ea32fd47dc40b7276);
#
#     });
# </script>

# %% [markdown]
# ### Scatter chart

# %%
from pyecharts import Scatter
scatter = Scatter("Scatter chart", "Annual precipitation and evaporation")
## xais_name is to set the horizontal ordinate name. Here due to the display issue, we need to set the distance for the y-axis.
scatter.add("Scatter distribution of precipitation and evaporation", data1,data2,xaxis_name="precipitation",yaxis_name="evaporation",
            yaxis_name_gap=40)
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="00e628de5b8349f8a7869f4b0f395224" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_00e628de5b8349f8a7869f4b0f395224 = echarts.init(document.getElementById('00e628de5b8349f8a7869f4b0f395224'), 'light', {renderer: 'canvas'});
#
# var option_00e628de5b8349f8a7869f4b0f395224 = {
#     "title": [
#         {
#             "text": "Scatter chart",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8813132,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "Scatter distribution of precipitation and evaporation",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     2.0,
#                     2.6
#                 ],
#                 [
#                     4.9,
#                     5.9
#                 ],
#                 [
#                     7.0,
#                     9.0
#                 ],
#                 [
#                     23.2,
#                     26.4
#                 ],
#                 [
#                     25.6,
#                     28.7
#                 ],
#                 [
#                     76.7,
#                     70.7
#                 ],
#                 [
#                     135.6,
#                     175.6
#                 ],
#                 [
#                     162.2,
#                     182.2
#                 ],
#                 [
#                     32.6,
#                     48.7
#                 ],
#                 [
#                     20.0,
#                     18.8
#                 ],
#                 [
#                     6.4,
#                     6.0
#                 ],
#                 [
#                     3.3,
#                     2.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8813132
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Scatter distribution of precipitation and evaporation"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "name": "precipitation",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "evaporation",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 40,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_00e628de5b8349f8a7869f4b0f395224.setOption(option_00e628de5b8349f8a7869f4b0f395224);
#
#     });
# </script>

# %% [markdown]
# ### Chart layout: combination of graphs

# %% [markdown]
# As the title and chart belong to different controls, the title position of the chart line must be set, otherwise the titles may be overlapped.

# %%
from pyecharts import Grid
## Set line chart title position
line = Line("Line chart","Annual precipitation and evaporation",title_top="45%")
line.add("precipitation", columns, data1, is_label_show=True)
line.add("evaporation", columns, data2, is_label_show=True)
grid = Grid()
## Set the relative position of the two charts
grid.add(bar, grid_bottom="60%")
grid.add(line, grid_top="60%")
grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f8f8904985874a6b8f74e779538f6e7d" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f8f8904985874a6b8f74e779538f6e7d = echarts.init(document.getElementById('f8f8904985874a6b8f74e779538f6e7d'), 'light', {renderer: 'canvas'});
#
# var option_f8f8904985874a6b8f74e779538f6e7d = {
#     "title": [
#         {
#             "text": "Bar chart",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         },
#         {
#             "text": "Line chart",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "auto",
#             "top": "45%",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 214954,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "precipitation",
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 214954,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {
#             "type": "bar",
#             "name": "evaporation",
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 214954,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {
#             "type": "line",
#             "name": "precipitation",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "Jan",
#                     2.0
#                 ],
#                 [
#                     "Feb",
#                     4.9
#                 ],
#                 [
#                     "Mar",
#                     7.0
#                 ],
#                 [
#                     "Apr",
#                     23.2
#                 ],
#                 [
#                     "May",
#                     25.6
#                 ],
#                 [
#                     "Jun",
#                     76.7
#                 ],
#                 [
#                     "Jul",
#                     135.6
#                 ],
#                 [
#                     "Aug",
#                     162.2
#                 ],
#                 [
#                     "Sep",
#                     32.6
#                 ],
#                 [
#                     "Oct",
#                     20.0
#                 ],
#                 [
#                     "Nov",
#                     6.4
#                 ],
#                 [
#                     "Dec",
#                     3.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }

# %%
from pyecharts import Overlap
overlap = Overlap()
bar = Bar("comb of bar chart and plot chart", "Annual precipitation and evaporation")
bar.add("precipitation", columns, data1, mark_point=["max", "min"])
bar.add("evaporation", columns, data2, mark_point=["max", "min"])
overlap.add(bar)
overlap.add(line)
overlap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="7bda8a1c7dea4acf8c4d4e189881e063" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_7bda8a1c7dea4acf8c4d4e189881e063 = echarts.init(document.getElementById('7bda8a1c7dea4acf8c4d4e189881e063'), 'light', {renderer: 'canvas'});
#
# var option_7bda8a1c7dea4acf8c4d4e189881e063 = {
#     "title": [
#         {
#             "text": "comb of bar chart and plot chart",
#             "subtext": "Annual precipitation and evaporation",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1444417,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "precipitation",
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1444417
#         },
#         {
#             "type": "bar",
#             "name": "evaporation",
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1444417
#         },
#         {
#             "type": "line",
#             "name": "precipitation",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "Jan",
#                     2.0
#                 ],
#                 [
#                     "Feb",
#                     4.9
#                 ],
#                 [
#                     "Mar",
#                     7.0
#                 ],
#                 [
#                     "Apr",
#                     23.2
#                 ],
#                 [
#                     "May",
#                     25.6
#                 ],
#                 [
#                     "Jun",
#                     76.7
#                 ],
#                 [
#                     "Jul",
#                     135.6
#                 ],
#                 [
#                     "Aug",
#                     162.2
#                 ],
#                 [
#                     "Sep",
#                     32.6
#                 ],
#                 [
#                     "Oct",
#                     20.0
#                 ],
#                 [
#                     "Nov",
#                     6.4
#                 ],
#                 [
#                     "Dec",
#                     3.3
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1444417,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {
#             "type": "line",

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Import related chart package.
# 2. Set basic information of the chart and create chart objects.
# 3. Use the add ( ) method for data input and chart setting (You can use print_echarts_ options( ) to output all configurable items).
# 4. Use render ( ) method to save chart

# %% [markdown]
# # A Real-World Case

# %% [markdown]
# In this case, we will implement Pyecharts along with some auxiliary tools to have an analysis of the author’s WeChat Friends (Under the Web Crawler license with all sensitive information eliminated).

# %% [markdown]
# Firstly, install the packages we need to use:

# %%
! pip install itchat
! pip install jieba
! pip install wordcloud

# %% [markdown]
# Then, import the required packages:

# %%
import itchat
import re
import jieba
import matplotlib.pyplot as plt
from wordcloud import WordCloud,ImageColorGenerator
import numpy as np
import PIL.Image as Image
from os import path
from imageio import imread
# Out:
# █

# %% [markdown]
# Login the author’s WeChat account via “itchat” method:

# %%
itchat.auto_login()#Scan the QR code and log in
friends = itchat.get_friends(update = True)#get WeChat friends' available information

# %% [markdown]
# Apply “pandas” to integrate all the available information in a DataFrame.

# %%
import pandas as pd
sex=list(map(lambda x:x['Sex'],friends[1:]))
nickname=list(map(lambda x:x['NickName'],friends[1:]))
signature=list(map(lambda x:x['Signature'],friends[1:]))
province=list(map(lambda x:x['Province'],friends[1:]))
city=list(map(lambda x:x['City'],friends[1:]))
headimg=list(map(lambda x:x['HeadImgUrl'],friends[1:]))
info={"nickname":nickname,"sex":sex,"province":province,"city":city,"signature":signature,'headimgurl':headimg}
data=pd.DataFrame(info)

# %% [markdown]
# Now, we can draw the plots with the DataFrame. First, let’s analysis the distribution of the author’s WeChat friends’ gender. Here we use the “Nightingale Rose Diagram”, where parts are separated with equal angle and area is the indication of proportion. We can observe that the author has more female friends than male friends, and there are also 9.02% of friends who don’t fill in their gender in WeChat (In WeChat, there is only 2 gender option, Male and Female):

# %%
from pyecharts import Pie
sexs=list(map(lambda x:x['Sex'],friends[1:])) #Get the gender of Wechat friends
value = [sexs.count(1), sexs.count(2), sexs.count(0)]#Count the amount of each gender
sex_attr=['Male','Female','Unknown']
pie = Pie('Sex Ratio of WeChat Friends', 'Total number of WeChat friends：%d' % len(sex), title_pos='center')
pie.add('', sex_attr, value, radius=[20, 50], rosetype='area', is_label_show=True,
        is_legend_show=True, legend_top='bottom')#Here we use "rosetype='area'" to get Nightingale rose diagram
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="55d2d4f993b1496084b1c07a71d6a96f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_55d2d4f993b1496084b1c07a71d6a96f = echarts.init(document.getElementById('55d2d4f993b1496084b1c07a71d6a96f'), 'light', {renderer: 'canvas'});
#
# var option_55d2d4f993b1496084b1c07a71d6a96f = {
#     "title": [
#         {
#             "text": "Sex Ratio of WeChat Friends",
#             "subtext": "Total number of WeChat friends\uff1a1806",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 45815,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "male",
#                     "value": 616
#                 },
#                 {
#                     "name": "female",
#                     "value": 1027
#                 },
#                 {
#                     "name": "unknown",
#                     "value": 163
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "50%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 45815
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "male",
#                 "female",
#                 "unknown"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "bottom",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_55d2d4f993b1496084b1c07a71d6a96f.setOption(option_55d2d4f993b1496084b1c07a71d6a96f);
#
#     });
# </script>

# %% [markdown]
# Then, we analysis the Top10 cities that the author’s friends located in with a bar plot. We observe that friends in the author’s two working place (Beijing & Shanghai) and hometown (Chengdu) make up a large proportion of the author’s WeChat friends. Besides, the rest 7 cities of Top10 are all the so called “first-tier” cities (developed cities) in China.

# %%
from pyecharts import Bar
from collections import Counter
city_10=Counter(city).most_common(10)
# Return the top 10 cities with highest frequency
bar = Bar("WeChat Friends' City Top10", '', title_pos='center', width=1200, height=500)
attr, value = bar.cast(city_10)
bar.add('', attr, value, is_visualmap=True, visual_text_color='#fff', is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b0ec25de1d7246fb833a0e9dad7c7761" style="width:1200px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b0ec25de1d7246fb833a0e9dad7c7761 = echarts.init(document.getElementById('b0ec25de1d7246fb833a0e9dad7c7761'), 'light', {renderer: 'canvas'});
#
# var option_b0ec25de1d7246fb833a0e9dad7c7761 = {
#     "title": [
#         {
#             "text": "WeChat Friends' City TOP10",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 5398226,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 312,
#                 166,
#                 104,
#                 42,
#                 39,
#                 25,
#                 21,
#                 17,
#                 16,
#                 12
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5398226
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Beijing",
#                 "Chengdu",
#                 "Shanghai",
#                 "Guangzhou",
#                 "Shenzhen",
#                 "Hangzhou",
#                 "Hongkong",
#                 "Chongqing",
#                 "Nanjing",
#                 "Changsha"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#fff"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_b0ec25de1d7246fb833a0e9dad7c7761.setOption(option_b0ec25de1d7246fb833a0e9dad7c7761);
#
#     });
# </script>

# %% [markdown]
# To make the location distribution more intuitive to read, we draw them on Chinese Maps. Note that we need to download the maps we would use before call the “Map” method. Here we download the maps:

# %%
! pip install echarts-countries-pypkg
! pip install echarts-china-provinces-pypkg
! pip install echarts-china-cities-pypkg
! pip install echarts-china-counties-pypkg

# %% [markdown]
# Then we can be obtained the distribution on Chinese Map with the following code.
#
# The Map is almost aligned with the bar plot we obtain above, we see that many friends located in Sichuan, Beijing, Shanghai and Guangdong. And the author’s friends are also located in the provinces adjacent to the three developed Cities/Province (Beijing, Shanghai and Guangdong). These provinces are shown in “yellow” color on the map, and the author has never been to some of them before, indicating the tendency that people in the nearby provinces are incline to work or study in the more developed places (The author also worked as an intern in those 3 cities/ provinces, thus the majority of friends were added there).

# %%
from pyecharts import Map
#Get the province frequency via "groupby" and "count" method for DataFrame
provinces_count = data.groupby('province', as_index=True)['province'].count().sort_values()
#If the location is not filled in, it will be changed to unknown
attr = list(map(lambda x: x if x != '' else 'unknown', list(provinces_count.index)))
value = list(provinces_count)
#Draw the Map for WeChat friends located in China
map_1 = Map("Province Distribution of Wechat Friends",title_pos="center",width=1000, height=500)
#Set "visual_range" to [0,120], making the provinces more differential to read
map_1.add('', attr, value, is_label_show=True, is_visualmap=True, visual_text_color='#000',visual_range=[0,120])
map_1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="c9ce11ef96c54a3b809c3097ad0f2c7b" style="width:1000px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_c9ce11ef96c54a3b809c3097ad0f2c7b = echarts.init(document.getElementById('c9ce11ef96c54a3b809c3097ad0f2c7b'), 'light', {renderer: 'canvas'});
#
# var option_c9ce11ef96c54a3b809c3097ad0f2c7b = {
#     "title": [
#         {
#             "text": "Province Distribution of Wechat Friends",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1704960,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 205
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 312
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 369
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 120,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_c9ce11ef96c54a3b809c3097ad0f2c7b.setOption(option_c9ce11ef96c54a3b809c3097ad0f2c7b);
#
#     });
# </script>

# %% [markdown]
# To give Sichuan Province as an example, we can also show how the WeChat friends are located at the City-Level. Instead of the default color range, we can also set our own color range, e.g. from cold color to warm color by setting “range_color”.
#
# The graph shows that the majority of the author’s WeChat friends in Sichuan located in Chengdu (the author’s hometown) and Chengdu’s adjacent cities. Since the majority of the friends in Sichuan are added during the author’s study in university (top 1 university in Sichuan Province), so this graph may also indicate the education qualities of different cities in Sichuan to some certain extent.

# %%
data_sc=data[data['province']=='四川']#Select friends whose province is Sichuan
cities_count = data_sc.groupby('city', as_index=True)['city'].count().sort_values()#Same method as above
attr = list(map(lambda x: x if x != '' else 'unknown', list(cities_count.index)))
value = list(cities_count)
map_2 = Map("City Distribution of Wechat Friends in Sichuan",title_pos="center",width=1000, height=500)
#instead of the default color range, we can also set our own color range, e.g. from cold color to warm color
range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
#For Provincial level map, we need to assign the province name via "maptype='四川'(SiChuan)"
map_2.add('', attr, value, is_label_show=True, is_visualmap=True, maptype='四川',
          visual_text_color='#000',visual_range=[0,50], visual_range_color=range_color)
map_2
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'sichuan': '/nbextensions/echarts-china-provinces-js/sichuan'
#         }
#     });
# </script>
#     <div id="d6481d73a2224524bc464f4891c116ac" style="width:1000px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'sichuan'], function(echarts) {
#
# var myChart_d6481d73a2224524bc464f4891c116ac = echarts.init(document.getElementById('d6481d73a2224524bc464f4891c116ac'), 'light', {renderer: 'canvas'});
#
# var option_d6481d73a2224524bc464f4891c116ac = {
#     "title": [
#         {
#             "text": "City Distribution of Wechat Friends in Sichuan",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5470146,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "\u56db\u5ddd",
#             "data": [
#                 {
#                     "name": "\u7518\u5b5c\u85cf\u65cf\u81ea\u6cbb\u5dde",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5e7f\u5143\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5185\u6c5f\u5e02",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5e7f\u5b89\u5e02",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6cf8\u5dde\u5e02",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u9042\u5b81\u5e02",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u96c5\u5b89\u5e02",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u8d44\u9633\u5e02",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u4e50\u5c71\u5e02",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5b9c\u5bbe\u5e02",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5357\u5145\u5e02",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u7709\u5c71\u5e02",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u51c9\u5c71\u5f5d\u65cf\u81ea\u6cbb\u5dde",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u81ea\u8d21\u5e02",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u6500\u679d\u82b1\u5e02",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5fb7\u9633\u5e02",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u7ef5\u9633\u5e02",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u6210\u90fd\u5e02",
#                     "value": 166
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 50,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#313695",
#                 "#4575b4",
#                 "#74add1",
#                 "#abd9e9",
#                 "#e0f3f8",
#                 "#ffffbf",
#                 "#fee090",
#                 "#fdae61",
#                 "#f46d43",
#                 "#d73027",
#                 "#a50026"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_d6481d73a2224524bc464f4891c116ac.setOption(option_d6481d73a2224524bc464f4891c116ac);
#
#     });
# </script>

# %% [markdown]
# Now, we implement the “jieba”, “wordcloud” and “snownlp” tools to analysis the signatures of the author’s friends. Firstly, we draw a word cloud of signatures with the following code:

# %%
import wordcloud# Use wordcloud package to draw the word cloud plot of WeChat friends' signatures
import jieba.analyse# "jieba" is a very popular package for word cutting
# "snownlp" is also a very popular package for text analysis, here we use it to get the emotion of signatures
import snownlp
plt.rcParams['font.sans-serif']=['SimHei']#Chinese can be displayed when drawing word cloud plot
plt.rcParams['axes.unicode_minus']=False#Chinese can be displayed when drawing word cloud plot

signatures = ''
emotions = []
for friend in friends:
    signature = friend['Signature']
    if signature != None:
        # Remove irrelevant content
        signature = signature.strip().replace("span","").replace("class","").replace("emoji","")
        signature = re.sub(r'1f(\d.+)',"",signature)
        
    # Only signature with length larger than 0 would be counted
    if len(signature) > 0:
        nlp = snownlp.SnowNLP(signature)
        emotions.append(nlp.sentiments)#nlp.sentiments：the probability that a signature tend to be optimistic
        signatures += " ".join(jieba.analyse.extract_tags(signature,5)) #get words from signatures via "jieba"
#We can use any plot as base plot to define the shape of word cloud plot
back_coloring = np.array(Image.open("/Users/wangshihang01/Downloads/Study/Wechat_logo.jpg"))
word_cloud2 = WordCloud(font_path = 'zt.ttf',
                        background_color = 'white',
                        max_words = 1200,
                        mask = back_coloring,
                        margin = 15)
word_cloud2.generate(signatures)
image_colors = ImageColorGenerator(back_coloring)
plt.figure(figsize=(6,5),dpi=160)
plt.imshow(word_cloud2.recolor(color_func=image_colors))
plt.axis("off")
plt.show()
word_cloud2.to_file("signatures.jpg")

# %% [markdown]
# The word cloud is displayed with the WeChat logo’s shape. It shows that the majorities of words are those with positive meaning, for instance, “Freedom”, “Tender”, “Like”, “Friends” etc. However, more works should be conduct to make more valid analysis.

# %% [markdown]
# Then, with the sentiment analysis results of “snownlp”, the author can also display the distribution of the friends’ sentiment (optimistic, pessimistic, neutral). (We can also customize our graph’s color via “label_color” here)

# %% [markdown]
# This result is aligned with the word cloud we obtained above, the majority of WeChat friends select an optimistic text as their signature, and only a little friends use pessimistic content as their own signature.

# %%
#Signature Sentiment
count_optimistic = len(list(filter(lambda x:x>0.66,emotions)))#Optimistic if the emo prob larger than 0.66
count_pessismistic = len(list(filter(lambda x:x<0.33,emotions)))#Pessismistic if the emo prob less than 0.33
count_neutral = len(list(filter(lambda x:x>=0.33 and x <= 0.66,emotions)))# else, neutral
value=[count_optimistic,count_neutral,count_pessismistic]
attr=['Optimistic','Neutral','Pessimistic']
pie = Pie('Sentiment Analysis of WeChat Friends Signatures', 
          'Total number of WeChat friends With Signature：%d' % sum(value),
          title_pos='center')
# with “rosetype=None”，a simple pie chart instead of Nightingale rose diagram is obtained
# here instead of using the default colors, we can also set our own colors via "label_color=" 
pie.add('', attr, value, radius=[20, 50], rosetype=None, is_label_show=True,
        is_legend_show=True, legend_top='bottom',label_color=['#a50026', '#f46d43', '#fdae61'])
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6a9da56777f64af4840c53eb477648a3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6a9da56777f64af4840c53eb477648a3 = echarts.init(document.getElementById('6a9da56777f64af4840c53eb477648a3'), 'light', {renderer: 'canvas'});
#
# var option_6a9da56777f64af4840c53eb477648a3 = {
#     "title": [
#         {
#             "text": "Emotional Analysis of WeChat Friends Signatures",
#             "subtext": "Total number of WeChat friends With Signature\uff1a982",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7626259,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "Optimistic",
#                     "value": 595
#                 },
#                 {
#                     "name": "Neutral",
#                     "value": 326
#                 },
#                 {
#                     "name": "Pessimistic",
#                     "value": 61
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "50%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 7626259
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Optimistic",
#                 "Neutral",
#                 "Pessimistic"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "bottom",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#a50026",
#         "#f46d43",
#         "#fdae61",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_6a9da56777f64af4840c53eb477648a3.setOption(option_6a9da56777f64af4840c53eb477648a3);
#
#     });
# </script>

# %% [markdown]
# With this case study above, the readers can have a clear view on how Pyecharts can be applied along with other popular Python tools to conduct interesting and valuable analysis in our academic and daily life.
